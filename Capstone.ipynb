# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/Users/MontayaMccloud/Downloads/Capstone Data.csv")

# %%
data.shape
# Out:
# (41, 8)

# %%
data.describe()
# Out:
#        Housing Starts  Housing Utilities   Inflation Rate   New Home Sales  \
# count       41.000000           41.000000        41.000000       41.000000
# mean      1466.682927          275.351976         3.263415      757.731707
# std        211.237123            9.435995         2.571649      116.760658
# min        938.000000          262.284000         0.100000      582.000000
# 25%       1273.000000          267.925000         1.500000      690.000000
# 50%       1514.000000          273.014000         1.900000      715.000000
# 75%       1617.000000          281.604000         5.400000      831.000000
# max       1810.000000          297.868000         8.600000     1036.000000
#
#        Home ownership rate  Housing Inventory
# count            41.000000          41.000000
# mean             64.824390        1381.707317
# std               1.130438         308.130674
# min              62.900000         860.000000
# 25%              63.900000        1150.000000
# 50%              64.800000        1400.000000
# 75%              65.400000        1590.000000
# max              67.900000        1920.000000

# %%
sns.pairplot(data)

# %%
import statsmodels.api as sm
x_train_sm = sm.add_constant(x_train)
lr = sm.OLS(y_train, x_train_sm).fit()
lr.params
lr.summary()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 import statsmodels.api as sm
#       2 x_train_sm = sm.add_constant(x_train)
#       3 lr = sm.OLS(y_train, x_train_sm).fit()
#
# ModuleNotFoundError: No module named 'statsmodels'
