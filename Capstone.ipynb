# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/Users/MontayaMccloud/Downloads/Capstone Data.csv")

# %%
data.shape
# Out:
# (41, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 41 non-null     object
#  1   Date                    41 non-null     object
#  2   Housing Starts          41 non-null     int64
#  3   Housing Utilities       41 non-null     float64
#  4   Inflation Rate          41 non-null     float64
#  5   New Home Sales          41 non-null     int64
#  6   Home ownership rate     41 non-null     float64
#  7   Construction Spending   41 non-null     int64
#  8   Mortgage rate           41 non-null     float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 3.0+ KB

# %%
data.describe()
# Out:
#        Housing Starts  Housing Utilities   Inflation Rate   New Home Sales  \
# count       41.000000           41.000000        41.000000       41.000000
# mean      1466.682927          275.351976         3.263415      757.731707
# std        211.237123            9.435995         2.571649      116.760658
# min        938.000000          262.284000         0.100000      582.000000
# 25%       1273.000000          267.925000         1.500000      690.000000
# 50%       1514.000000          273.014000         1.900000      715.000000
# 75%       1617.000000          281.604000         5.400000      831.000000
# max       1810.000000          297.868000         8.600000     1036.000000
#
#        Home ownership rate  Construction Spending   Mortgage rate
# count            41.000000               41.000000      41.000000
# mean             64.824390             1401.463415       1.160976
# std               1.130438              304.167396       0.428881
# min              62.900000              860.000000       0.400000
# 25%              63.900000             1160.000000       0.900000
# 50%              64.800000             1420.000000       1.200000
# 75%              65.400000             1630.000000       1.400000
# max              67.900000             1920.000000       2.000000

# %%
sns.pairplot(data)
