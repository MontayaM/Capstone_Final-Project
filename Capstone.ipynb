# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/Users/MontayaMccloud/Downloads/Capstone Data.csv")

# %%
data.shape
# Out:
# (41, 10)

# %%
data.describe()
# Out:
#        Housing Starts  Housing Utilities   Inflation Rate   New Home Sales  \
# count       41.000000           41.000000        41.000000       41.000000
# mean      1466.682927          275.351976         3.263415      757.731707
# std        211.237123            9.435995         2.571649      116.760658
# min        938.000000          262.284000         0.100000      582.000000
# 25%       1273.000000          267.925000         1.500000      690.000000
# 50%       1514.000000          273.014000         1.900000      715.000000
# 75%       1617.000000          281.604000         5.400000      831.000000
# max       1810.000000          297.868000         8.600000     1036.000000
#
#        Home ownership rate  Construction Spending   Mortgage rate  Unnamed: 9
# count            41.000000               41.000000      41.000000         0.0
# mean             64.824390             1401.463415       1.160976         NaN
# std               1.130438              304.167396       0.428881         NaN
# min              62.900000              860.000000       0.400000         NaN
# 25%              63.900000             1160.000000       0.900000         NaN
# 50%              64.800000             1420.000000       1.200000         NaN
# 75%              65.400000             1630.000000       1.400000         NaN
# max              67.900000             1920.000000       2.000000         NaN

# %%
sns.pairplot(data)
